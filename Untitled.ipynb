# %%
import pandas as pd
cars=pd.Series(['mercedies',"toyota","sizuki","maruti"])
colors=pd.Series(['black','blue','white','red'])
df=pd.DataFrame({"cars":cars,
                 "colors":colors
                })
print(df)
# Out:
#         cars colors
# 0  mercedies  black
# 1     toyota   blue
# 2     sizuki  white
# 3     maruti    red
